# %% [markdown]
# <a href="https://colab.research.google.com/github/dmcghee173268/CS4410/blob/main/Homework2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes

# %%
diabetes = load_diabetes()

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
diabetes.data.shape
# Out:
# (442, 10)

# %%
diabetes.target.shape
# Out:
# (442,)

# %%
diabetes.feature_names
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
import pandas as pd

# %%
pd.set_option('precision', 4)

# %%
pd.set_option('max_columns', 9)

# %%
pd.set_option('display.width', None)

# %%
diabetes_df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

# %%
diabetes_df['oneYearPrediction'] = pd.Series(diabetes.target)

# %%
diabetes_df.head()
# Out:
#       age     sex     bmi      bp  ...      s4      s5      s6  \
# 0  0.0381  0.0507  0.0617  0.0219  ... -0.0026  0.0199 -0.0176
# 1 -0.0019 -0.0446 -0.0515 -0.0263  ... -0.0395 -0.0683 -0.0922
# 2  0.0853  0.0507  0.0445 -0.0057  ... -0.0026  0.0029 -0.0259
# 3 -0.0891 -0.0446 -0.0116 -0.0367  ...  0.0343  0.0227 -0.0094
# 4  0.0054 -0.0446 -0.0364  0.0219  ... -0.0026 -0.0320 -0.0466
#
#    oneYearPrediction
# 0              151.0
# 1               75.0
# 2              141.0
# 3              206.0
# 4              135.0
#
# [5 rows x 11 columns]

# %%
diabetes_df.describe()
# Out:
#               age         sex         bmi          bp  ...          s4  \
# count  4.4200e+02  4.4200e+02  4.4200e+02  4.4200e+02  ...  4.4200e+02
# mean  -3.6396e-16  1.3099e-16 -8.0140e-16  1.2898e-16  ...  3.8632e-16
# std    4.7619e-02  4.7619e-02  4.7619e-02  4.7619e-02  ...  4.7619e-02
# min   -1.0723e-01 -4.4642e-02 -9.0275e-02 -1.1240e-01  ... -7.6395e-02
# 25%   -3.7299e-02 -4.4642e-02 -3.4229e-02 -3.6656e-02  ... -3.9493e-02
# 50%    5.3831e-03 -4.4642e-02 -7.2838e-03 -5.6706e-03  ... -2.5923e-03
# 75%    3.8076e-02  5.0680e-02  3.1248e-02  3.5644e-02  ...  3.4309e-02
# max    1.1073e-01  5.0680e-02  1.7056e-01  1.3204e-01  ...  1.8523e-01
#
#                s5          s6  oneYearPrediction
# count  4.4200e+02  4.4200e+02           442.0000
# mean  -3.8481e-16 -3.3985e-16           152.1335
# std    4.7619e-02  4.7619e-02            77.0930
# min   -1.2610e-01 -1.3777e-01            25.0000
# 25%   -3.3249e-02 -3.3179e-02            87.0000
# ...

# %%
sample_df = diabetes_df.sample(frac=0.1, random_state=17)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.set(font_scale=2)

# %%
sns.set_style('whitegrid')

# %%
for feature in diabetes.feature_names:
            plt.figure(figsize=(16,9))
            sns.scatterplot(data=sample_df, x=feature, y='oneYearPrediction', hue='oneYearPrediction', palette='cool', legend = False)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, random_state=11)

# %%
X_train.shape
# Out:
# (331, 10)

# %%
X_test.shape
# Out:
# (111, 10)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
for i, name in enumerate(diabetes.feature_names): print(f'{name:>10}: {linear_regression.coef_[i]}')
# Out:
#        age: -60.221893331882335
#        sex: -266.45890749037505
#        bmi: 523.0596748020042
#         bp: 310.51485159166873
#         s1: -336.17030792547865
#         s2: 137.344544538294
#         s3: -131.13560429688624
#         s4: -1.1485501589064313
#         s5: 622.3374924905781
#         s6: 60.46751763603552

# %%
linear_regression.intercept_
# Out:
# 152.22835839334243

# %%
predicted = linear_regression.predict(X_test)

# %%
expected = y_test

# %%
predicted[:5]
# Out:
# array([115.46727109,  83.46033257, 160.77912055, 187.65807631,
#         72.72355267])

# %%
expected[:5]
# Out:
# array([ 79.,  55., 109., 178.,  39.])

# %%
df = pd.DataFrame()

# %%
df['Expected'] = pd.Series(expected)

# %%
df['Predicted'] = pd.Series(predicted)

# %%
figure = plt.figure(figsize=(9,9))

# %%
axes = sns.scatterplot(data=df, x='Expected', y='Predicted', hue='Predicted', palette='cool', legend=False)

# %%
start = min(expected.min(), predicted.min())

# %%
end = max(expected.max(), predicted.max())

# %%
axes.set_xlim(start, end)
# Out:
# (37.0, 332.0)

# %%
axes.set_ylim(start, end)
# Out:
# (37.0, 332.0)

# %%
line = plt.plot([start, end], [start, end], 'k--')

# %%
from sklearn import metrics

# %%
metrics.r2_score(expected, predicted)
# Out:
# 0.5322440129151977

# %%
metrics.mean_squared_error(expected, predicted)
# Out:
# 3458.2229332614693

# %%
from sklearn.linear_model import ElasticNet, Lasso, Ridge

# %%
estimators = { 'LinearRegression': linear_regression, 'ElasticNet': ElasticNet(), 'Lasso': Lasso(), 'Ridge': Ridge() }

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
for estimator_name, estimator_object in estimators.items():
    kfold = KFold(n_splits=10, random_state=11, shuffle=True)
    scores = cross_val_score(estimator=estimator_object, 
        X=diabetes.data, y=diabetes.target, cv=kfold,
        scoring='r2')
    print(f'{estimator_name:>16}: ' + 
          f'mean of r2 scores={scores.mean():.3f}')
# Out:
# LinearRegression: mean of r2 scores=0.475
#       ElasticNet: mean of r2 scores=-0.002
#            Lasso: mean of r2 scores=0.339
#            Ridge: mean of r2 scores=0.421
